# %%
import pandas as pd
import datetime
import numpy as np
import itertools
from ipykernel import kernelapp as app
# %load_ext Cython
import numba
import gc
global df
from datetime import timedelta
# Out:
# The Cython extension is already loaded. To reload it, use:
#   %reload_ext Cython

# %%
#filter data to those buses that are at the stop and whose traveltime is 0.0 because we are
# only interested in the timetables from terminus
df = pd.read_hdf("cleaned_store.h5", key="table_name", where="TravelTime == 0.0 and At_Stop == 1")

# %%
df.head()
# Out:
#               Timestamp Journey_Pattern_ID Time_Frame Vehicle_Journey_ID  \
# 0   2012-11-12 13:28:20           056A0001 2012-11-12               2070
# 24  2012-11-12 13:20:06           017A1003 2012-11-12               6114
# 78  2012-11-12 13:08:37           015A1001 2012-11-12               3095
# 114 2012-11-12 13:25:22           077A1001 2012-11-12               4905
# 203 2012-11-12 13:15:02           01500001 2012-11-12               1519
#
#     Bus_Operator  Longitude   Latitude  Delay_seconds Block_ID Vehicle_ID  \
# 0             RD  -6.233867  53.342285              0    56002      24549
# 24            HN  -6.152884  53.389900              4   171009      24587
# 78            RD  -6.334367  53.307034              0    15015      24606
# 114           RD  -6.427166  53.290718            328    27017      24623
# 203           RD  -6.258533  53.346085              0   150004      33009
#
#     Stop_ID  At_Stop  Week_Day  Distance  TravelTime TimeCategory  Rain  Temp  \
# 0       395        1         0       0.0         0.0     13:30:00   0.0  13.6
# 24      956        1         0       0.0         0.0     13:30:00   0.0  13.6
# 78     1105        1         0       0.0         0.0     13:00:00   0.0  13.6
# 114    4713        1         0       0.0         0.0     13:30:00   0.0  13.6
# 203     337        1         0       0.0         0.0     13:30:00   0.0  13.6
#
#      windSpeed
# 0         4.27
# 24        4.27
# 78        4.27
# 114       4.27
# 203       4.27

# %%
len(df)
# Out:
# 22813

# %%
def map_day(x):
    if x <= 4:
        return "Mon-Fr"
    elif x == 5 :
        return "Sat"
    else:
        return "Sun"

# %%
#created category for day in database
df["Day_Cat"] = df["Week_Day"].apply(map_day)

# %%
#sum or subtract delay from timestamp to get correct time
df["Timestamp_plus_delay"] = df['Timestamp'] - pd.to_timedelta(df['Delay_seconds'], unit='s')

# %%
#round time to remove duplicates later on
df["Timestamp_plus_delay"] = pd.DatetimeIndex(df['Timestamp_plus_delay']).round('10min')

# %%
#eliminated date from datetime of correct timestamp
df["Time_no_date"] = pd.DatetimeIndex(df['Timestamp_plus_delay']).time

# %%
df = df[["Journey_Pattern_ID", "Delay_seconds","Stop_ID","Day_Cat", "Time_no_date"]]

# %%
different_journey_patterns = df["Journey_Pattern_ID"].value_counts().index

# %%
list_of_dfs = []
for journey in different_journey_patterns:
    
    #filter dataframe based on journey
    df_temp = df[df["Journey_Pattern_ID"] == journey]
    #groupby stops
    grouped = df_temp.groupby("Stop_ID")
    #get size of each group of stops
    grouped_df = grouped.size().reset_index()
    #rename columns
    grouped_df.columns = ['Stop_ID', 'Count']
    #sort by values
    grouped_df.sort_values(["Count"], ascending=False, inplace=True)
    grouped_df.reset_index(inplace=True, drop=True)
    print(grouped_df.head())
    #take stop id with largest count
    stop_id_value  = grouped_df.loc[0, "Stop_ID"]
    print(stop_id_value)
    #filter df_temp by this stop_id and its journey id and store in a temporary list
    df_temp = df_temp[df_temp["Stop_ID"] == stop_id_value]
    df_temp.head()
    list_of_dfs.append(df_temp)
    
new_df = pd.concat(list_of_dfs)
# Out:
#   Stop_ID  Count
# 0    1491    548
# 1    1492      1
# 2    1939      1
# 1491
#   Stop_ID  Count
# 0     293    433
# 293
#   Stop_ID  Count
# 0    5171    414
# 5171
#   Stop_ID  Count
# 0    4795    390
# 1    4799      1
# 4795
#   Stop_ID  Count
# 0    6318    366
# 1    6319      2
# 2    6320      2
# 3     348      1
# 4    4719      1
# 6318
#   Stop_ID  Count
# 0    4592    364
# 4592
#   Stop_ID  Count
# 0    6057    333
# 1    4514      1
# 6057
#   Stop_ID  Count
# 0    1772    328
# 1    1776      1
# 1772
#   Stop_ID  Count
# 0    2353    318
# 1    1196      1
# 2    4643      1
# 2353
#   Stop_ID  Count
# 0    1423    317
# 1    1424      1
# 1423
#   Stop_ID  Count
# 0    7157    295
# 1    7158      8
# 2    4747      3
# 3    1858      1
# 4    1909      1
# 7157
#   Stop_ID  Count
# 0    4533    278
# 1     770      3
# 2    4844      2
# 3    3148      1
# 4    4182      1
# 4533
#   Stop_ID  Count
# 0    1105    284
# 1105
#   Stop_ID  Count
# 0     291    283
# 291
#   Stop_ID  Count
# 0    4843    268
# 1    4905      2
# 2    4909      1
# 4843
#   Stop_ID  Count
# 0    4747    268
# 4747
#   Stop_ID  Count
# 0    7132    264
# 1    6228      3
# 2      37      1
# 7132
#   Stop_ID  Count
# 0    4863    267
# 4863
#   Stop_ID  Count
# 0     337    265
# 1    1279      1
# 337
#   Stop_ID  Count
# 0     300    260
# 300
#   Stop_ID  Count
# 0     896    259
# 1     319      1
# 896
#   Stop_ID  Count
# 0    7333    247
# 7333
#   Stop_ID  Count
# 0     950    246
# 950
#   Stop_ID  Count
# 0    6285    245
# 6285
#   Stop_ID  Count
# 0    4359    244
# 4359
#   Stop_ID  Count
# 0    4525    234
# 4525
#   Stop_ID  Count
# 0    4747    228
# 4747
#   Stop_ID  Count
# 0    7077    226
# 7077
#   Stop_ID  Count
# 0    7077    214
# 7077
#   Stop_ID  Count
# 0    4620    214
# 4620
#   Stop_ID  Count
# 0     956    209
# 1     959      1
# 956
#   Stop_ID  Count
# 0    3917    199
# 3917
#   Stop_ID  Count
# 0    7391    197
# 7391
#   Stop_ID  Count
# 0    6041    189
# 1     248      1
# 2    2826      1
# 3    4708      1
# 6041
#   Stop_ID  Count
# 0    4606    185
# 1    2278      2
# 2    7142      2
# 4606
#   Stop_ID  Count
# 0    4342    188
# 1    4348      1
# 4342
#   Stop_ID  Count
# 0    4843    186
# 4843
#   Stop_ID  Count
# 0    7514    183
# 1    2279      1
# 7514
#   Stop_ID  Count
# 0     299    183
# 299
#   Stop_ID  Count
# 0     381    182
# 381
#   Stop_ID  Count
# 0    5161    177
# 5161
#   Stop_ID  Count
# 0     284    165
# 1    4504      1
# 284
#   Stop_ID  Count
# 0    2670    164
# 1    2663      1
# 2    2664      1
# 2670
#   Stop_ID  Count
# 0     298    165
# 1     515      1
# 298
#   Stop_ID  Count
# 0     289    163
# 1     525      1
# 2     533      1
# 289
#   Stop_ID  Count
# 0     395    162
# 1    1934      1
# 2    2313      1
# 3    7459      1
# 395
#   Stop_ID  Count
# 0    6004    163
# 6004
#   Stop_ID  Count
# 0    3980    162
# 3980
#   Stop_ID  Count
# 0    2039    159
# 1    2045      1
# 2     772      1
# 2039
#   Stop_ID  Count
# 0    4713    159
# 1    2570      1
# 2     354      1
# 4713
#   Stop_ID  Count
# 0    7073    157
# 7073
#   Stop_ID  Count
# 0    7157    155
# 7157
#   Stop_ID  Count
# 0    7330    144
# 1     332      2
# 2    2051      1
# 3      91      1
# 7330
#   Stop_ID  Count
# 0    7391    147
# 7391
#   Stop_ID  Count
# 0     807    132
# 1    6059      2
# 2     760      2
# 3    2039      1
# 4     761      1
# 807
#   Stop_ID  Count
# 0    4320    136
# 1    6000      1
# 4320
#   Stop_ID  Count
# 0     300    131
# 300
#   Stop_ID  Count
# 0    7333    130
# 7333
#   Stop_ID  Count
# 0    7391    130
# 7391
#   Stop_ID  Count
# 0     324    127
# 1    7500      1
# 324
#   Stop_ID  Count
# 0    4657    121
# 1    4151      1
# 2    7279      1
# 4657
#   Stop_ID  Count
# 0    6030    120
# 6030
#   Stop_ID  Count
# 0    7149    119
# 7149
#   Stop_ID  Count
# 0    2243    117
# 1    5007      1
# 2243
#   Stop_ID  Count
# 0    6235    116
# 1     270      1
# 6235
#   Stop_ID  Count
# 0     289    116
# 289
#   Stop_ID  Count
# 0     385    115
# 385
#   Stop_ID  Count
# 0    7391    114
# 7391
#   Stop_ID  Count
# 0    5044    109
# 1    7329      1
# 5044
#   Stop_ID  Count
# 0    3605    104
# 1    3606      2
# 3605
#   Stop_ID  Count
# 0     208    105
# 208
#   Stop_ID  Count
# 0    1380    103
# 1    1400      1
# 1380
#   Stop_ID  Count
# 0    4342    103
# 4342
#   Stop_ID  Count
# 0    1791    103
# 1791
#   Stop_ID  Count
# 0    7391    102
# 7391
#   Stop_ID  Count
# 0    7067    101
# 7067
#   Stop_ID  Count
# 0    2037     99
# 2037
#   Stop_ID  Count
# 0    4713     99
# 4713
#   Stop_ID  Count
# 0    4392     97
# 4392
#   Stop_ID  Count
# 0    6290     97
# 6290
#   Stop_ID  Count
# 0    7348     96
# 7348
#   Stop_ID  Count
# 0    3624     91
# 3624
#   Stop_ID  Count
# 0     324     91
# 324
#   Stop_ID  Count
# 0     767     88
# 1     768      1
# 767
#   Stop_ID  Count
# 0    6282     86
# 6282
#   Stop_ID  Count
# 0    7333     86
# 7333
#   Stop_ID  Count
# 0     288     85
# 288
#   Stop_ID  Count
# 0     342     83
# 342
#   Stop_ID  Count
# 0    7333     83
# 7333
#   Stop_ID  Count
# 0    3222     80
# 1    4962      2
# 2     495      1
# 3222
#   Stop_ID  Count
# 0    7391     82
# 7391
#   Stop_ID  Count
# 0    4344     79
# 4344
#   Stop_ID  Count
# 0     248     79
# 248
#   Stop_ID  Count
# 0    6004     78
# 6004
#   Stop_ID  Count
# 0    4177     78
# 4177
#   Stop_ID  Count
# 0    7333     77
# 7333
#   Stop_ID  Count
# 0    2037     76
# 2037
#   Stop_ID  Count
# 0     337     76
# 337
#   Stop_ID  Count
# 0    7391     74
# 7391
#   Stop_ID  Count
# 0     336     72
# 336
#   Stop_ID  Count
# 0     324     70
# 1    7484      1
# 324
#   Stop_ID  Count
# 0    5013     69
# 1    4460      1
# 5013
#   Stop_ID  Count
# 0    1174     68
# 1174
#   Stop_ID  Count
# 0    4319     58
# 1    3665      9
# 4319
#   Stop_ID  Count
# 0    7391     66
# 7391
#   Stop_ID  Count
# 0     324     64
# 1    1938      1
# 2    6235      1
# 324
#   Stop_ID  Count
# 0    3222     66
# 3222
#   Stop_ID  Count
# 0     449     59
# 1      10      2
# 2    6122      1
# 449
#   Stop_ID  Count
# 0     395     62
# 395
#   Stop_ID  Count
# 0     288     62
# 288
#   Stop_ID  Count
# 0    6185     61
# 6185
#   Stop_ID  Count
# 0    6200     60
# 6200
#   Stop_ID  Count
# 0    3665     58
# 1    4319      2
# 3665
#   Stop_ID  Count
# 0    4177     60
# 4177
#   Stop_ID  Count
# 0    1730     59
# 1730
#   Stop_ID  Count
# 0    4962     57
# 4962
#   Stop_ID  Count
# 0    4564     56
# 4564
#   Stop_ID  Count
# 0    3085     56
# 3085
#   Stop_ID  Count
# 0    7347     54
# 1     213      1
# 7347
#   Stop_ID  Count
# 0    4595     54
# 4595
#   Stop_ID  Count
# 0    4495     53
# 4495
#   Stop_ID  Count
# 0    4495     52
# 4495
#   Stop_ID  Count
# 0     326     51
# 326
#   Stop_ID  Count
# 0     326     49
# 326
#   Stop_ID  Count
# 0    6048     47
# 6048
#   Stop_ID  Count
# 0    6122     47
# 6122
#   Stop_ID  Count
# 0    2038     47
# 2038
#   Stop_ID  Count
# 0    4260     46
# 4260
#   Stop_ID  Count
# 0    5111     44
# 5111
#   Stop_ID  Count
# 0     381     44
# 381
#   Stop_ID  Count
# 0    5189     44
# 5189
#   Stop_ID  Count
# 0     292     44
# 292
#   Stop_ID  Count
# 0     289     43
# 289
#   Stop_ID  Count
# 0    4341     43
# 4341
#   Stop_ID  Count
# 0    2492     43
# 2492
#   Stop_ID  Count
# 0    7073     41
# 7073
#   Stop_ID  Count
# 0     226     40
# 226
#   Stop_ID  Count
# 0    7514     40
# 7514
#   Stop_ID  Count
# 0     324     39
# 324
#   Stop_ID  Count
# 0    3333     39
# 3333
#   Stop_ID  Count
# 0    3250     38
# 3250
#   Stop_ID  Count
# 0    6004     38
# 6004
#   Stop_ID  Count
# 0    1828     37
# 1828
#   Stop_ID  Count
# 0     342     35
# 1    1279      1
# 342
#   Stop_ID  Count
# 0    2210     36
# 2210
#   Stop_ID  Count
# 0    7073     35
# 7073
#   Stop_ID  Count
# 0    1828     34
# 1828
#   Stop_ID  Count
# 0    4747     34
# 4747
#   Stop_ID  Count
# 0    2037     34
# 2037
#   Stop_ID  Count
# 0    4330     34
# 4330
#   Stop_ID  Count
# 0    2039     33
# 2039
#   Stop_ID  Count
# 0    4168     31
# 4168
#   Stop_ID  Count
# 0     956     30
# 956
#   Stop_ID  Count
# 0    7229     30
# 7229
#   Stop_ID  Count
# 0    4863     29
# 4863
#   Stop_ID  Count
# 0    4606     29
# 4606
#   Stop_ID  Count
# 0    3813     29
# 3813
#   Stop_ID  Count
# 0    3222     28
# 3222
#   Stop_ID  Count
# 0     407     28
# 407
#   Stop_ID  Count
# 0     300     27
# 300
#   Stop_ID  Count
# 0    4381     27
# 4381
#   Stop_ID  Count
# 0    4747     27
# 4747
#   Stop_ID  Count
# 0    4747     26
# 4747
#   Stop_ID  Count
# 0    3544     25
# 3544
#   Stop_ID  Count
# 0    4795     25
# 4795
#   Stop_ID  Count
# 0    1375     25
# 1375
#   Stop_ID  Count
# 0    6235     24
# 6235
#   Stop_ID  Count
# 0    4096     23
# 1    4118      1
# 4096
#   Stop_ID  Count
# 0    4495     24
# 4495
#   Stop_ID  Count
# 0     707     24
# 707
#   Stop_ID  Count
# 0    7229     23
# 7229
#   Stop_ID  Count
# 0     292     23
# 292
#   Stop_ID  Count
# 0    7144     23
# 7144
#   Stop_ID  Count
# 0     289     23
# 289
#   Stop_ID  Count
# 0     896     23
# 896
#   Stop_ID  Count
# 0    2934     22
# 2934
#   Stop_ID  Count
# 0    2037     22
# 2037
#   Stop_ID  Count
# 0     395     22
# 395
#   Stop_ID  Count
# 0    4003     22
# 4003
#   Stop_ID  Count
# 0     401     22
# 401
#   Stop_ID  Count
# 0    3085     21
# 3085
#   Stop_ID  Count
# 0    2934     21
# 2934
#   Stop_ID  Count
# 0    4745     21
# 4745
#   Stop_ID  Count
# 0     324     20
# 1     296      1
# 324
#   Stop_ID  Count
# 0    4962     20
# 4962
#   Stop_ID  Count
# 0    3088     18
# 1    3704      1
# 2    3705      1
# 3088
#   Stop_ID  Count
# 0    4962     20
# 4962
#   Stop_ID  Count
# 0     265     20
# 265
#   Stop_ID  Count
# 0    7026     20
# 7026
#   Stop_ID  Count
# 0    5047     18
# 1     485      1
# 5047
#   Stop_ID  Count
# 0    4664     19
# 4664
#   Stop_ID  Count
# 0     299     18
# 299
#   Stop_ID  Count
# 0     395     18
# 395
#   Stop_ID  Count
# 0    5189     17
# 5189
#   Stop_ID  Count
# 0    5013     17
# 5013
#   Stop_ID  Count
# 0     284     17
# 284
#   Stop_ID  Count
# 0    3057     16
# 3057
#   Stop_ID  Count
# 0    4260     16
# 4260
#   Stop_ID  Count
# 0    4962     16
# 4962
#   Stop_ID  Count
# 0    6048     16
# 6048
#   Stop_ID  Count
# 0    4843     16
# 4843
#   Stop_ID  Count
# 0    7026     16
# 7026
#   Stop_ID  Count
# 0    4952     16
# 4952
#   Stop_ID  Count
# 0    3732     16
# 3732
#   Stop_ID  Count
# 0    5047     16
# 5047
#   Stop_ID  Count
# 0     226     15
# 226
#   Stop_ID  Count
# 0    6004     15
# 6004
#   Stop_ID  Count
# 0     324     15
# 324
#   Stop_ID  Count
# 0     215     15
# 215
#   Stop_ID  Count
# 0    3994     15
# 3994
#   Stop_ID  Count
# 0    5171     15
# 5171
#   Stop_ID  Count
# 0    3605     15
# 3605
#   Stop_ID  Count
# 0    4307     14
# 4307
#   Stop_ID  Count
# 0    2353     14
# 2353
#   Stop_ID  Count
# 0     485     14
# 485
#   Stop_ID  Count
# 0     300     14
# 300
#   Stop_ID  Count
# 0    3283     13
# 1    2039      1
# 3283
#   Stop_ID  Count
# 0    4168     14
# 4168
#   Stop_ID  Count
# 0    4202     14
# 4202
#   Stop_ID  Count
# 0    4495     14
# 4495
#   Stop_ID  Count
# 0    4745     14
# 4745
#   Stop_ID  Count
# 0    7157     14
# 7157
#   Stop_ID  Count
# 0    4952     14
# 4952
#   Stop_ID  Count
# 0    1174     14
# 1174
#   Stop_ID  Count
# 0    4952     14
# 4952
#   Stop_ID  Count
# 0    4260     13
# 4260
#   Stop_ID  Count
# 0    4953     13
# 4953
#   Stop_ID  Count
# 0     318     13
# 318
#   Stop_ID  Count
# 0    3921     12
# 1    3922      1
# 3921
#   Stop_ID  Count
# 0    6235     13
# 6235
#   Stop_ID  Count
# 0     318     13
# 318
#   Stop_ID  Count
# 0    6041     13
# 6041
#   Stop_ID  Count
# 0     289     13
# 289
#   Stop_ID  Count
# 0    2825     13
# 2825
#   Stop_ID  Count
# 0    1184     12
# 1184
#   Stop_ID  Count
# 0    4952     12
# 4952
#   Stop_ID  Count
# 0    4962     12
# 4962
#   Stop_ID  Count
# 0    2038     12
# 2038
#   Stop_ID  Count
# 0    4342     12
# 4342
#   Stop_ID  Count
# 0    7333     12
# 7333
#   Stop_ID  Count
# 0    4795     12
# 4795
#   Stop_ID  Count
# 0    3143     11
# 3143
#   Stop_ID  Count
# 0    4745     11
# 4745
#   Stop_ID  Count
# 0    4316     11
# 4316
#   Stop_ID  Count
# 0    3890     11
# 3890
#   Stop_ID  Count
# 0    2492     11
# 2492
#   Stop_ID  Count
# 0    2060     11
# 2060
#   Stop_ID  Count
# 0    4495     11
# 4495
#   Stop_ID  Count
# 0    4952     10
# 4952
#   Stop_ID  Count
# 0    3400     10
# 3400
#   Stop_ID  Count
# 0    4595     10
# 4595
#   Stop_ID  Count
# 0     337     10
# 337
#   Stop_ID  Count
# 0     686     10
# 686
#   Stop_ID  Count
# 0    3641     10
# 3641
#   Stop_ID  Count
# 0    4260     10
# 4260
#   Stop_ID  Count
# 0    7333     10
# 7333
#   Stop_ID  Count
# 0     401     10
# 401
#   Stop_ID  Count
# 0    3586     10
# 3586
#   Stop_ID  Count
# 0     289     10
# 289
#   Stop_ID  Count
# 0    1380     10
# 1380
#   Stop_ID  Count
# 0    2825      9
# 2825
#   Stop_ID  Count
# 0    4686      9
# 4686
#   Stop_ID  Count
# 0     324      9
# 324
#   Stop_ID  Count
# 0    7077      9
# 7077
#   Stop_ID  Count
# 0    3980      9
# 3980
#   Stop_ID  Count
# 0     298      9
# 298
#   Stop_ID  Count
# 0     768      9
# 768
#   Stop_ID  Count
# 0    3333      9
# 3333
#   Stop_ID  Count
# 0    4495      9
# 4495
#   Stop_ID  Count
# 0    3088      9
# 3088
#   Stop_ID  Count
# 0    3085      9
# 3085
#   Stop_ID  Count
# 0    3085      9
# 3085
#   Stop_ID  Count
# 0     288      9
# 288
#   Stop_ID  Count
# 0     557      9
# 557
#   Stop_ID  Count
# 0    4341      8
# 4341
#   Stop_ID  Count
# 0    3606      8
# 3606
#   Stop_ID  Count
# 0     300      8
# 300
#   Stop_ID  Count
# 0    4391      8
# 4391
#   Stop_ID  Count
# 0    3677      8
# 3677
#   Stop_ID  Count
# 0     300      8
# 300
#   Stop_ID  Count
# 0     226      8
# 226
#   Stop_ID  Count
# 0    6057      7
# 6057
#   Stop_ID  Count
# 0     297      7
# 297
#   Stop_ID  Count
# 0    4714      7
# 4714
#   Stop_ID  Count
# 0     324      7
# 324
#   Stop_ID  Count
# 0     264      7
# 264
#   Stop_ID  Count
# 0    2353      7
# 2353
#   Stop_ID  Count
# 0     896      7
# 896
#   Stop_ID  Count
# 0    4167      7
# 4167
#   Stop_ID  Count
# 0     289      7
# 289
#   Stop_ID  Count
# 0    6048      7
# 6048
#   Stop_ID  Count
# 0    4495      7
# 4495
#   Stop_ID  Count
# 0    2270      7
# 2270
#   Stop_ID  Count
# 0    4592      7
# 4592
#   Stop_ID  Count
# 0    3283      7
# 3283
#   Stop_ID  Count
# 0    5044      7
# 5044
#   Stop_ID  Count
# 0    4843      7
# 4843
#   Stop_ID  Count
# 0    3593      7
# 3593
#   Stop_ID  Count
# 0    7330      6
# 7330
#   Stop_ID  Count
# 0    3815      6
# 3815
#   Stop_ID  Count
# 0    4953      6
# 4953
#   Stop_ID  Count
# 0    3980      6
# 3980
#   Stop_ID  Count
# 0    2037      6
# 2037
#   Stop_ID  Count
# 0    4745      6
# 4745
#   Stop_ID  Count
# 0    6185      6
# 6185
#   Stop_ID  Count
# 0    1423      6
# 1423
#   Stop_ID  Count
# 0     324      6
# 324
#   Stop_ID  Count
# 0    2060      6
# 2060
#   Stop_ID  Count
# 0    4169      6
# 4169
#   Stop_ID  Count
# 0    7187      6
# 7187
#   Stop_ID  Count
# 0     567      6
# 567
#   Stop_ID  Count
# 0    3921      6
# 3921
#   Stop_ID  Count
# 0    1491      6
# 1491
#   Stop_ID  Count
# 0    4003      6
# 4003
#   Stop_ID  Count
# 0    4592      6
# 4592
#   Stop_ID  Count
# 0    4843      6
# 4843
#   Stop_ID  Count
# 0     208      6
# 208
#   Stop_ID  Count
# 0    4843      5
# 4843
#   Stop_ID  Count
# 0    4952      5
# 4952
#   Stop_ID  Count
# 0    3283      5
# 3283
#   Stop_ID  Count
# 0    7132      5
# 7132
#   Stop_ID  Count
# 0    2039      5
# 2039
#   Stop_ID  Count
# 0    6318      5
# 6318
#   Stop_ID  Count
# 0    7188      5
# 7188
#   Stop_ID  Count
# 0     336      5
# 336
#   Stop_ID  Count
# 0    4952      5
# 4952
#   Stop_ID  Count
# 0    4923      5
# 4923
#   Stop_ID  Count
# 0    4525      5
# 4525
#   Stop_ID  Count
# 0     849      5
# 849
#   Stop_ID  Count
# 0    3400      5
# 3400
#   Stop_ID  Count
# 0    7067      5
# 7067
#   Stop_ID  Count
# 0    1176      5
# 1176
#   Stop_ID  Count
# 0    4564      5
# 4564
#   Stop_ID  Count
# 0    3057      4
# 3057
#   Stop_ID  Count
# 0    5189      4
# 5189
#   Stop_ID  Count
# 0    4108      4
# 4108
#   Stop_ID  Count
# 0     289      4
# 289
#   Stop_ID  Count
# 0    7229      4
# 7229
#   Stop_ID  Count
# 0    3890      4
# 3890
#   Stop_ID  Count
# 0    3400      4
# 3400
#   Stop_ID  Count
# 0     763      4
# 763
#   Stop_ID  Count
# 0    4606      4
# 4606
#   Stop_ID  Count
# 0    4495      4
# 4495
#   Stop_ID  Count
# 0     274      4
# 274
#   Stop_ID  Count
# 0    4177      4
# 4177
#   Stop_ID  Count
# 0     208      4
# 208
#   Stop_ID  Count
# 0    7230      4
# 7230
#   Stop_ID  Count
# 0    5189      4
# 5189
#   Stop_ID  Count
# 0    7026      4
# 7026
#   Stop_ID  Count
# 0     319      4
# 319
#   Stop_ID  Count
# 0    7289      4
# 7289
#   Stop_ID  Count
# 0     848      3
# 848
#   Stop_ID  Count
# 0    7067      3
# 7067
#   Stop_ID  Count
# 0     215      3
# 215
#   Stop_ID  Count
# 0    4533      3
# 4533
#   Stop_ID  Count
# 0    4962      3
# 4962
#   Stop_ID  Count
# 0    4320      3
# 4320
#   Stop_ID  Count
# 0    7073      3
# 7073
#   Stop_ID  Count
# 0    2060      3
# 2060
#   Stop_ID  Count
# 0    4168      3
# 4168
#   Stop_ID  Count
# 0    4745      3
# 4745
#   Stop_ID  Count
# 0    3640      3
# 3640
#   Stop_ID  Count
# 0    4420      3
# 4420
#   Stop_ID  Count
# 0    2038      3
# 2038
#   Stop_ID  Count
# 0    4151      3
# 4151
#   Stop_ID  Count
# 0    7188      3
# 7188
#   Stop_ID  Count
# 0     300      3
# 300
#   Stop_ID  Count
# 0    1828      3
# 1828
#   Stop_ID  Count
# 0     767      2
# 767
#   Stop_ID  Count
# 0    7433      2
# 7433
#   Stop_ID  Count
# 0    2064      2
# 2064
#   Stop_ID  Count
# 0     288      2
# 288
#   Stop_ID  Count
# 0     292      2
# 292
#   Stop_ID  Count
# 0    4167      2
# 4167
#   Stop_ID  Count
# 0     760      2
# 760
#   Stop_ID  Count
# 0     765      2
# 765
#   Stop_ID  Count
# 0    3032      2
# 3032
#   Stop_ID  Count
# 0    7230      2
# 7230
#   Stop_ID  Count
# 0     324      2
# 324
#   Stop_ID  Count
# 0    3994      2
# 3994
#   Stop_ID  Count
# 0    6164      2
# 6164
#   Stop_ID  Count
# 0     226      2
# 226
#   Stop_ID  Count
# 0    4320      2
# 4320
#   Stop_ID  Count
# 0     767      2
# 767
#   Stop_ID  Count
# 0     289      2
# 289
#   Stop_ID  Count
# 0    3057      1
# 3057
#   Stop_ID  Count
# 0     422      1
# 422
#   Stop_ID  Count
# 0    4686      1
# 4686
#   Stop_ID  Count
# 0    1796      1
# 1796
#   Stop_ID  Count
# 0     395      1
# 395
#   Stop_ID  Count
# 0     772      1
# 772
#   Stop_ID  Count
# 0    4420      1
# 4420
#   Stop_ID  Count
# 0    7229      1
# 7229
#   Stop_ID  Count
# 0    4167      1
# 4167
#   Stop_ID  Count
# 0     288      1
# 288
#   Stop_ID  Count
# 0    4238      1
# 4238
#   Stop_ID  Count
# 0    7149      1
# 7149
#   Stop_ID  Count
# 0    4096      1
# 4096
#   Stop_ID  Count
# 0    3605      1
# 3605
#   Stop_ID  Count
# 0     279      1
# 279
#   Stop_ID  Count
# 0    7270      1
# 7270
#   Stop_ID  Count
# 0    7347      1
# 7347
#   Stop_ID  Count
# 0    4168      1
# 4168
#   Stop_ID  Count
# 0     288      1
# 288
#   Stop_ID  Count
# 0    6048      1
# 6048
#   Stop_ID  Count
# 0    3732      1
# 3732
#   Stop_ID  Count
# 0    4177      1
# 4177
#   Stop_ID  Count
# 0    4392      1
# 4392
#   Stop_ID  Count
# 0    4167      1
# 4167
#   Stop_ID  Count
# 0     292      1
# 292
#   Stop_ID  Count
# 0    2039      1
# 2039
#   Stop_ID  Count
# 0    7188      1
# 7188
#   Stop_ID  Count
# 0    2955      1
# 2955
#   Stop_ID  Count
# 0    7347      1
# 7347
#   Stop_ID  Count
# 0    4108      1
# 4108
#   Stop_ID  Count
# 0    6282      1
# 6282
#   Stop_ID  Count
# 0    3815      1
# 3815
#   Stop_ID  Count
# 0    3514      1
# 3514
#   Stop_ID  Count
# 0    3593      1
# 3593
#   Stop_ID  Count
# 0     281      1
# 281
#   Stop_ID  Count
# 0     265      1
# 265
#   Stop_ID  Count
# 0     289      1
# 289
#   Stop_ID  Count
# 0    4167      1
# 4167

# %%
new_df.drop(["Delay_seconds", "Stop_ID"], inplace=True, axis=1)

# %%
new_df.drop_duplicates(inplace=True)

# %%
len(new_df)
# Out:
# 17821

# %%
new_df_temp = new_df[new_df["Journey_Pattern_ID"] == "039A0001"]

# %%
new_df_temp.sort_values(["Day_Cat","Time_no_date"], ascending=True, inplace=True)
new_df_temp.reset_index(inplace=True, drop=True)
# Out:
# C:\Users\Daniele\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
#these timestamps look very promising, let us write everything to mysql database
new_df.sort_values(["Journey_Pattern_ID","Day_Cat","Time_no_date"], ascending=True, inplace=True)
new_df.reset_index(inplace=True, drop=True)

# %%
new_df.to_csv("Timetable.csv",index=False)
